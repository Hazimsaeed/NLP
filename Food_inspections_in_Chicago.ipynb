# %% [markdown]
# I Use Python Regular Expressions to identify top-10 most frequent causes of failed food inspections in Chicago.

# %%
import re
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random
import sklearn as sk
import os
import math
os.getcwd()
# Out:
# '/Users/hazim'

# %%
df = pd.read_csv("~/Downloads/NLP/Week1/Assignment1/Food_Inspections.csv", error_bad_lines = False, encoding='latin-1')
df.head(2)

df = df[df.Results =='Fail']
df
# Out:
#         Inspection ID                                           DBA Name  \
# 0             2313193                                             Talman
# 2             2315234                                         LA HUACANA
# 6             2313166                                         EL COSTENO
# 9             2313125                                        SHAKE SHACK
# 14            2313176                                   BETTY'S ICECREAM
# 20            2313112                                   ELLA'S BBQ, INC.
# 26            2313154                                  TRADER JOE'S #706
# 32            2313120                                        SHAKE SHACK
# 35            2313153                                  TRADER JOE'S #706
# 36            2313119                                        SHU TIN XIA
# 43            2313152                                   FRUITERIA FAVELA
# 44            2313110                                    SAWYER  (ANNEX)
# ...

# %% [markdown]
# Now select only the column of interest:

# %%
df = df[df.Results =='Fail']
output = ''
for x in df['Violations']:
    output += '|'
    output += str(x).strip()

txt=output.split('|')

# %% [markdown]
# Clean the text I have and split it in list

# %%
while('' in txt) : 
    txt.remove('')

result=[]    
for x in txt:
    output = str(x).lstrip()
    #output = output.replace('-', '')
    result.append(output) 

txt_clean = [x for x in result if str(x) != 'nan']

# %% [markdown]
# Creat list called cleanedresult has only the text we are interested to count

# %%
cleanedresult =[]
find = r"(\d{1,2}\.\s.+?) -"
for x in txt_clean:
    cleanedresult.append(re.findall(find,x))

# %% [markdown]
# Put the text we are interested in a dataframe so easily we can count the most common and print out the result

# %%
df_count = pd.DataFrame({'text':cleanedresult})
df_count['text'].value_counts().head(10)
# Out:
# [34. FLOORS: CONSTRUCTED PER CODE, CLEANED, GOOD REPAIR, COVING INSTALLED, DUST-LESS CLEANING METHODS USED]                                     19342
# [35. WALLS, CEILINGS, ATTACHED EQUIPMENT CONSTRUCTED PER CODE: GOOD REPAIR, SURFACES CLEAN AND DUST-LESS CLEANING METHODS]                      18224
# [33. FOOD AND NON-FOOD CONTACT EQUIPMENT UTENSILS CLEAN, FREE OF ABRASIVE DETERGENTS]                                                           16426
# [18. NO EVIDENCE OF RODENT OR INSECT OUTER OPENINGS PROTECTED/RODENT PROOFED, A WRITTEN LOG SHALL BE MAINTAINED AVAILABLE TO THE INSPECTORS]    16417
# [38. VENTILATION: ROOMS AND EQUIPMENT VENTED AS REQUIRED: PLUMBING: INSTALLED AND MAINTAINED]                                                   15507
# [32. FOOD AND NON-FOOD CONTACT SURFACES PROPERLY DESIGNED, CONSTRUCTED AND MAINTAINED]                                                          14994
# ...
